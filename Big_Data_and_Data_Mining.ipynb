# %% [markdown]
# <a href="https://colab.research.google.com/github/PythonDecorator/Zpp.-App/blob/Big-Data/Big_Data_and_Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📈 **MSC AI & DATA SCIENCE ASSIGNMENT**
#
# ---
#
#
# > **Module**: Big Data and Data Mining <br>
# **Assignment Title**: Accident and Social Network Data Analysis  <br>
# **Student Name**: Amos Orevaoghene Okpe  <br>
# **Student ID**:  202536977  <br>
# **Start Date**: October 2025
#
# ---

# %% [markdown]
# <p align="center">
#   <img src="https://res.cloudinary.com/dhqdentd8/image/upload/v1759870220/cover_image_wmrayf.jpg" width="100%" alt="Data Science Icon"/>
# </p>

# %% [markdown]
# # 🧠 **Abstract**
#
# This report presents findings from analyses of two real-world datasets: UK 2019 road traffic accidents and a Facebook social network. Accident data is examined for patterns and used to build models predicting accident rates and severity. Facebook network data is analysed for structural properties and community formation. The project applies data mining and machine learning methods to both, yielding recommendations for road safety policy and insights into social connectivity.

# %% [markdown]
# # 📘 **Introduction**
#
# Big data analytics is essential for understanding complex systems such as transport safety and online social interaction. This project analyses two datasets: UK road accident records from 2019 and a Facebook network sample from SNAP. Both sets enable exploration of trends, prediction, and underlying patterns, with practical implications for public safety and network science.

# %% [markdown]
# # 🎯 **Aim**
#
#  - ## Road Accident Analysis:
#
#         ✔️ Investigate patterns in accident frequency, vehicle/casualty details, and location.
#
#         ✔️ Build predictive models for accident occurrence and severity.
#
#         ✔️ Recommend data-driven interventions for road safety.
#
# <br>
#
#  - ## Social Network Analysis:
#
#         ✔️ Construct and study the Facebook network.
#
#         ✔️ Analyse centrality and detect communities.
#
#         ✔️ Draw insights relevant to network science and user connectivity.

# %% [markdown]
# # 🗂️ **Data Sources and Licensing**
#
# - ## Road Traffic Accident Data (2019)
#         Contains all recorded UK road accidents in 2019, including `accident details`, `vehicle characteristics`, `casualty information`, and `location identifiers` (LSOA, police region, etc.).
#         👉 Source: UK Road Safety Data
#         👉 License: Open Government Licence v3.0
#
# <br>
#
# - ## Lower Layer Super Output Area (LSOA) Boundaries
#         Geospatial boundaries used for mapping and analysis of accident locations.
#         👉 Source: ONS LSOA Dec 2001
#         👉 License: Open Government Licence v3.0
#         👉 Copyright: Contains OS data © Crown copyright and database right 2023
#
# <br>
#
# - ## Facebook Social Network Data
#         Edge list representing user connections (egonets) for social network analysis.
#         👉 Source: Stanford Network Analysis Platform (SNAP), J. Leskovec and A. Krevl. SNAP Datasets: Stanford Large Network Dataset Collection
#         👉 Usage: Research and educational purposes under SNAP terms

# %% [markdown]
# <p align="center">
#   <img src="https://res.cloudinary.com/dhqdentd8/image/upload/v1752880346/intro_image_2_yffflh.jpg
# " width="100%" alt="Python Data Science Image"/>
# </p>
#
# ---

# %% [markdown]
# # 👉 **Import Statements**

# %%
# Importing Python libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 👉 **Mount Google Drive**
#
# > 📁 **Working from Google Drive**
#
# If you're **not using Google Drive**, feel free to **skip or comment out** the next code cell.

# %%
# Mount Google Drive (only needed if you're running from Google Colab and using Drive)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 👉 **Define Constant Variables**

# %%
# controls if we want to save plot images
SAVE_PLOTS = True
ACCIDENT_DATA_PATH = "/content/drive/MyDrive/University of Hull/Big Data and Data Mining/accident_data_v1.0.0_2023.db"
SOCIAL_NETWORK_DATA_PATH = "/content/drive/MyDrive/University of Hull/Big Data and Data Mining/social_media_data_set_facebook_combined-1.txt"

# define plot colors
PLOT_COLORS = {
    'red': '#FF0000',
    'green': '#00FF00',
    'primary': '#007bff',
    'secondary': '#6c757d',
    'gray': '#6c757d',
    'dark': '#343a40'
}

# %%
def save_plot(fig, name):
    """Helper to save figures. Returns the filename."""
    filename = f"{name}.png"
    fig.savefig(filename, dpi=300, bbox_inches='tight')
    print(f"✅ Saved plot {filename}")
    return filename

# %% [markdown]
# # 👉 **Load Data**

# %% [markdown]
# # 👉 **Exploratory Data Analysis (EDA) - Accident Data**

# %% [markdown]
# > # Tasks

# %% [markdown]
# # 📈 **(a) Report on Accidents**

# %% [markdown]
# ## 🧮 Task 1
#
# ### Investigate accident frequency by hour and day of week.
#
# Test whether road traffic accidents in 2019 are concentrated at particular hours of day and days of week, quantify the magnitude of any peaks, establish statistical significance, and provide robust, evidence-based interpretations that can inform policy.

# %% [markdown]
# ## Visualisations

# %% [markdown]
# ### Hourly line plot (0–23)
#
# - Caption: “Accident counts by hour of day (2019).”

# %% [markdown]
# ### Weekly bar chart (Mon → Sun) — counts and % of total.
#
# - Caption: “Accident counts by day of week (2019).”

# %% [markdown]
# ### Weekday × Hour heatmap — intensity (counts) shown as colour; annotating hotspots.
#
# - Title: Heatmap of accidents: weekday (rows) vs hour (columns)

# %% [markdown]
# ### Proportion table: top 3 peak hours and top 3 peak days (counts and % of total).

# %% [markdown]
# ### Faceted plots: hourly patterns stratified by severity (slight/serious/fatal).

# %% [markdown]
# # 📈 **(b) Social Network Analysis**

# %% [markdown]
# # 👉 **Load Data**

# %% [markdown]
# # 👉 **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ## 🧮 Task 1

# %% [markdown]
# <p align="center">
#   <img src="https://res.cloudinary.com/dhqdentd8/image/upload/v1752880345/closing_image_yjg6dq.jpg
# " width="100%" alt="Closing Image"/>
# </p>
#
# ---
